# %% [markdown]
# # PROBE

# %%
print('AAA no meta')
# Out:
# AAA no meta

# %%
print('BBB source_hidden only')
# Out:
# BBB source_hidden only

# %%
print('CCC source_hidden + collapsed')
# Out:
# CCC source_hidden + collapsed

# %%
print('DDD collapsed only')
# Out:
# DDD collapsed only
